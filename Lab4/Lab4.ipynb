# %%
#2.1.1. Phương pháp Otsu
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pylab as plt
from skimage.filters.thresholding import threshold_otsu
data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')
a = np.asarray(data)
# performing Otsu's thresholding
thres = threshold_otsu (a)
# pixels with intensity greater than theshold are kept
b = a > thres
b = Image.fromarray (b)
plt.imshow(b)
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\X'
# <>:8: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\HOANG HIEP\AppData\Local\Temp\ipykernel_17704\3026508010.py:8: SyntaxWarning: invalid escape sequence '\X'
#   data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')

# %%
#2.1.2. Phương pháp Adaptive Thresholding
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pylab as plt
from skimage.filters import threshold_local
data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')
a = np.asarray (data)
# performing local thresholding
b = threshold_local (a, 39, offset=10)
b = Image.fromarray(b)
plt.imshow (b)
plt.show ()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\X'
# <>:8: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\HOANG HIEP\AppData\Local\Temp\ipykernel_17704\3358303309.py:8: SyntaxWarning: invalid escape sequence '\X'
#   data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')

# %%
#2.2. Phân vùng theo region
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
from scipy.ndimage import label
import matplotlib.pylab as plt
from skimage.filters import threshold_local

data = cv2.imread('D:\XLA_lab4\exercise\dalat.jpg')

a = cv2.cvtColor (data, cv2.COLOR_BGR2GRAY)

thresh, bl = cv2.threshold(a, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

b2 = cv2.erode (bl, None, iterations = 2)

dist_trans = cv2.distanceTransform (b2, 2, 3)

thresh, dt = cv2.threshold (dist_trans, 1, 255, cv2.THRESH_BINARY)

labelled, ncc = label (dt)

labelled = labelled.astype (np.int32)

cv2.watershed(data, labelled)
b = Image.fromarray (labelled)
plt.imshow (b)
plt.show ()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\HOANG HIEP\AppData\Local\Temp\ipykernel_17704\1859036720.py:11: SyntaxWarning: invalid escape sequence '\X'
#   data = cv2.imread('D:\XLA_lab4\exercise\dalat.jpg')

# %%
#2.3.1. Sử dụng binary_dilation
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
from scipy.ndimage import label
import matplotlib.pylab as plt
from skimage.filters import threshold_local
# opening the image and converting it to grayscale
data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')
b = nd.binary_dilation(data, iterations=50)
c= Image.fromarray(b)
c.show()
plt.imshow (c)
plt.show ()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\HOANG HIEP\AppData\Local\Temp\ipykernel_17704\3548411306.py:11: SyntaxWarning: invalid escape sequence '\X'
#   data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')

# %%
#2.3.2. Sử dụng binary_opening
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
from scipy.ndimage import label
import matplotlib.pylab as plt
from skimage.filters import threshold_local
# opening the image and converting it to grayscale
data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')
# defining the structuring element
s= [[0, 1, 0], [1, 1, 1], [0, 1, 0]]
b = nd.binary_opening (data, structure=s, iterations=25)
c = Image.fromarray(b)
c.show ()
plt.imshow(c)
plt.show ()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\HOANG HIEP\AppData\Local\Temp\ipykernel_17704\1103324190.py:11: SyntaxWarning: invalid escape sequence '\X'
#   data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')

# %%
#2.3.3. Sử dụng binary_erosion
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
from scipy.ndimage import label
import matplotlib.pylab as plt
from skimage.filters import threshold_local
#opening the image and converting it to grayscale
data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')
#defining the structuring element
s= [[0, 1, 0], [1, 1, 1], [0, 1, 0]]

b = nd.binary_erosion(data, structure=s, iterations=50)
c = Image.fromarray (b)
c.show ()
plt.imshow (c)
plt.show ()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\HOANG HIEP\AppData\Local\Temp\ipykernel_17704\1898308500.py:11: SyntaxWarning: invalid escape sequence '\X'
#   data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')

# %%
#2.3.4. Sử dụng binary_closing
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as np
from scipy.ndimage import label
import matplotlib.pylab as plt
from skimage.filters import threshold_local
# opening the image and converting it to grayscale
data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')
# defining the structuring element
s = [[0, 1, 0], [1, 1, 1], [0, 1, 0]]
b= nd.binary_closing (data, structure=s, iterations=50)
c= Image.fromarray (b)
c.show ()
plt.imshow(c)
plt.show ()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# <>:11: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\HOANG HIEP\AppData\Local\Temp\ipykernel_17704\3305723013.py:11: SyntaxWarning: invalid escape sequence '\X'
#   data = Image.open('D:\XLA_lab4\exercise\dalat.jpg').convert('L')

# %%
#bai1
import cv2
import numpy as np
from skimage.filters import threshold_otsu
import matplotlib.pyplot as plt

img = cv2.imread('exercise/dalat.jpg', cv2.IMREAD_GRAYSCALE)

langbiang = img[0:400, 0:500]


otsu_thresh = threshold_otsu(langbiang)
manual_thresh = otsu_thresh * 0.3
binary = (langbiang > manual_thresh).astype(np.uint8) * 255

shifted = np.zeros_like(binary)
if binary.shape[1] > 100:
    shifted[:, 100:] = binary[:, :-100]


cv2.imwrite('lang_biang.jpg', shifted)
plt.imshow(shifted, cmap='gray')

plt.axis('off')
plt.show()

# %%
#bai2
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('exercise/dalat.jpg', cv2.IMREAD_GRAYSCALE)

ho_xuan_huong = img[0:700, 500:1000] 

rows, cols = ho_xuan_huong.shape
M = cv2.getRotationMatrix2D((cols/2, rows/2), 45, 1)
rotated = cv2.warpAffine(ho_xuan_huong, M, (cols, rows))

adaptive = cv2.adaptiveThreshold(rotated, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                               cv2.THRESH_BINARY, 11, 60)


cv2.imwrite('ho_xuan_huong.jpg', adaptive)
plt.imshow(adaptive, cmap='gray')

plt.axis('off')
plt.show()

# %%
#bai3
import cv2
import numpy as np
from scipy.ndimage import binary_closing
import matplotlib.pyplot as plt

img = cv2.imread('exercise/dalat.jpg', cv2.IMREAD_GRAYSCALE)
quan_truong = img[0:400, 1000:1500]  

mask = np.zeros_like(quan_truong)
mask[50:450, 50:550] = 1  
closed = binary_closing(quan_truong * mask, structure=np.ones((5,5)))


cv2.imwrite('quan_truong_lam_vien.jpg', closed.astype(np.uint8) * 255)
plt.imshow(closed, cmap='gray')

plt.axis('off')
plt.show()

# %%
#bai4
import cv2
import numpy as np
from skimage.filters import threshold_otsu
from scipy.ndimage import binary_dilation, binary_erosion

def process_image(img, geo_func=None, seg_func=None):
    # Geometric transformations
    if geo_func == "rotate":
        rows, cols = img.shape
        M = cv2.getRotationMatrix2D((cols/2, rows/2), 45, 1)
        img = cv2.warpAffine(img, M, (cols, rows))
    elif geo_func == "scale":
        img = cv2.resize(img, None, fx=1.5, fy=1.5)
    elif geo_func == "shift":
        M = np.float32([[1, 0, 100], [0, 1, 0]])
        img = cv2.warpAffine(img, M, (img.shape[1], img.shape[0]))
    
    # Segmentation methods
    if seg_func == "adaptive_thresholding":
        img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                  cv2.THRESH_BINARY, 11, 60)
    elif seg_func == "binary_dilation":
        img = binary_dilation(img, structure=np.ones((5,5))).astype(np.uint8) * 255
    elif seg_func == "binary_erosion":
        img = binary_erosion(img, structure=np.ones((5,5))).astype(np.uint8) * 255
    elif seg_func == "otsu":
        thresh = threshold_otsu(img)
        img = (img > thresh).astype(np.uint8) * 255
    
    return img

# Main program
img = cv2.imread('exercise/dalat.jpg', cv2.IMREAD_GRAYSCALE)

print("""
Chọn chức năng xử lý:
geometric_transformation:
  1. coordinate_mapping
  2. rotate
  3. scale
  4. shift
segment:
  5. adaptive_thresholding
  6. binary_dilation
  7. binary_erosion
  8. otsu
""")

choices = input("Nhập số chức năng (cách nhau bằng dấu cách): ").split()
geo_func = None
seg_func = None

for choice in choices:
    if choice == "1": geo_func = "coordinate_mapping"
    elif choice == "2": geo_func = "rotate"
    elif choice == "3": geo_func = "scale"
    elif choice == "4": geo_func = "shift"
    elif choice == "5": seg_func = "adaptive_thresholding"
    elif choice == "6": seg_func = "binary_dilation"
    elif choice == "7": seg_func = "binary_erosion"
    elif choice == "8": seg_func = "otsu"

result = process_image(img, geo_func, seg_func)
cv2.imwrite('output.jpg', result)
print("Đã xử lý và lưu ảnh thành công")
# Out:
# Chọn chức năng xử lý:
# geometric_transformation:
#   1. coordinate_mapping
#   2. rotate
#   3. scale
#   4. shift
# segment:
#   5. adaptive_thresholding
#   6. binary_dilation
#   7. binary_erosion
#   8. otsu
# Đã xử lý và lưu ảnh thành công
